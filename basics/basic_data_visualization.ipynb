# %% [markdown]
# ### DATA VISUALIZATION USING MATPLOTLIB
# ```bash
# pip install matplotlib
# ```

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## BARCHART

# %%
categories = ['Math', 'Science', 'English', 'PE']
scores = [88, 92, 80, 76]

# Plot
plt.bar(categories, scores, color='skyblue', edgecolor='black')

# Labels and title
plt.title("Student Scores by Subject")
plt.xlabel("Subjects")
plt.ylabel("Scores")
plt.grid(axis='y', linestyle='--', linewidth=0.5)

# Show
plt.show()

# %% [markdown]
# ## HISTOGRAM

# %%
# Sample data (like test scores)
scores = [67, 70, 71, 73, 75, 77, 78, 79, 81, 82, 83, 85, 88, 89, 90, 92, 95]

# Plot
plt.hist(scores, bins=5, color='orange', edgecolor='black')

# Labels and title
plt.title("Distribution of Exam Scores")
plt.xlabel("Score Range")
plt.ylabel("Number of Students")
plt.grid(axis='y', linestyle='--', linewidth=0.5)

# Show
plt.show()

# %% [markdown]
# ## LINEPLOT

# %%
# Data: x = days, y = stock prices
x = [1, 2, 3, 4, 5]            
y = [100, 120, 115, 140, 160] 

# Plotting the line graph with basic customizations
plt.plot(
    x, y,
    color='blue',          # Line color
    linestyle='--',        # Dashed line style
    linewidth=2,           # Thickness of the line
    marker='o',            # Marker style (circle)
    markersize=6,          # Size of the markers
    label='Stock A'        # Label for legend
)

# Add title and axis labels
plt.title("Stock Prices Over 5 Days")  # Graph title
plt.xlabel("Day")                      # X-axis label
plt.ylabel("Price ($)")                # Y-axis label

# Add gridlines to improve readability
plt.grid(True)

# Display the legend (uses the label from plt.plot)
plt.legend()

# Save and Show the plot
plt.show()

# %% [markdown]
# ## SCATTERPLOT

# %%
# Sample data
study_hours = [1, 2, 3, 4, 5, 6, 7]
grades = [50, 55, 65, 70, 75, 85, 95]

# Plot
plt.scatter(study_hours, grades, color='purple', s=80, alpha=0.7)

# Labels and title
plt.title("Study Hours vs. Grades")
plt.xlabel("Hours Studied")
plt.ylabel("Grade")
plt.grid(True)

# Show
plt.show()
